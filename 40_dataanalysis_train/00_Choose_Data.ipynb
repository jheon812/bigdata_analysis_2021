# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_mh = pd.read_csv('Mental Health Checker.csv')
df_mh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 36 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Timestamp                                                                              207 non-null    object
#  1   Select your gender                                                                     207 non-null    object
#  2   How old are you?                                                                       207 non-null    object
#  3   Education                                                                              192 non-null    object
#  4   Marital status                                                                         207 non-null    object
# ...

# %%
df_happy = pd.read_csv('Mental_Health_Checker.csv')
df_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          207 non-null    object
#  1   gender             207 non-null    object
#  2   age                207 non-null    object
#  3   education          192 non-null    object
#  4   marital            207 non-null    object
#  5   income             207 non-null    object
#  6   loan               207 non-null    object
#  7   friend_no          207 non-null    object
#  8   friend_help        207 non-null    object
#  9   friend_interact    207 non-null    object
#  10  share_feel         207 non-null    object
#  11  have_someone       207 non-null    object
#  12  lonely             207 non-null    object
#  13  bullied            207 non-null    object
#  14  family_support     207 non-null    object
#  15  compare_life       207 non-null    object
# ...

# %%
df_mh.describe()
# Out:
#                            Timestamp Select your gender How old are you?  \
# count                            207                207              207
# unique                           207                  2                5
# top     2021/05/17 11:46:36 PM GMT+6               Male            20-26
# freq                               1                113              126
#
#          Education Marital status Income Do you have any loan?  \
# count          192            207    207                   207
# unique           3              4      5                     2
# top     University         single    <10                    no
# freq           148            181    160                   179
#
#        How many friends do you have? Do you think your friends are helpful?  \
# count                            207                                    207
# unique                             5                                      3
# ...

# %%
df_happy.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...
